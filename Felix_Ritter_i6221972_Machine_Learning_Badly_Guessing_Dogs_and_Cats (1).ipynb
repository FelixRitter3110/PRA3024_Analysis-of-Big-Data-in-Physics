# %% [markdown]
# **Biggus Datus Week 4 - Machine Learning CNN**
#
# *@author Felix Ritter (i6229172)*
#
# Code description at end of code

# %%
# Some data-handling functions to download/import.

# from https://github.com/yandexdataschool/mlhep2018/blob/master/day2-Tue/seminar-03-keras-cnn/seminar_tf_keras.ipynb
"""I load some cifar"""

import numpy as np
from sklearn.model_selection import train_test_split
import os, sys
if sys.version_info[0] == 2:
    from urllib import urlretrieve
    import cPickle as pickle

else:
    from urllib.request import urlretrieve
    import pickle

def unpickle(file):
    fo = open(file, 'rb')
    if sys.version_info[0] == 2:
        dict = pickle.load(fo)
    else:
        dict = pickle.load(fo,encoding='latin1')
    
    fo.close()
    return dict




def download_cifar10(path,
                     url='https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
                     tarname='cifar-10-python.tar.gz',):
    import tarfile
    if not os.path.exists(path):
        os.mkdir(path)
    
        

    urlretrieve(url, os.path.join(path,tarname))
    tfile = tarfile.open(os.path.join(path,tarname))
    tfile.extractall(path=path)
    

def load_cifar10(data_path=".",channels_last=False,test_size=0.2,random_state=1337):
    
    test_path = os.path.join(data_path,"cifar-10-batches-py/test_batch")
    train_paths = [os.path.join(data_path,"cifar-10-batches-py/data_batch_%i"%i) for i in range(1,6)]
    
    if not os.path.exists(test_path) or not all(list(map(os.path.exists, train_paths))):
        print ("Dataset not found. Downloading...")
        download_cifar10(data_path)

    train_batches = list(map(unpickle,train_paths))
    test_batch = unpickle(test_path)

    X = np.concatenate([batch["data"] for batch in train_batches]).reshape([-1,3,32,32]).astype('float32')/255
    y = np.concatenate([batch["labels"] for batch in train_batches]).astype('int32')
    X_train,X_val,y_train,y_val = train_test_split(X,y,
                                                   test_size=test_size,
                                                   random_state=random_state)
    
    X_test = test_batch["data"].reshape([-1,3,32,32]).astype('float32')/255
    y_test = np.array(test_batch["labels"]).astype('int32')
    
    if channels_last:
        #convert from [batch,3,H,W] to [batch,H,W,3]
        #WARNING! Make this is only necessary for tensorflow-style dim order
        #If you use theano-style dimensions in keras config, skip this cell
        X_train = X_train.transpose([0,2,3,1])
        X_val   = X_val.transpose([0,2,3,1])
        X_test  = X_test.transpose([0,2,3,1])

    
    return X_train,y_train,X_val,y_val,X_test,y_test

# %%
import tensorflow as tf
#gpu_options = tf.GPUOptions(allow_growth=True, per_process_gpu_memory_fraction=0.1) # restricts GPU load for multi-user nodes

import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.4.1
# 2.4.3

# %%
# Load the data samples

x_train,y_train,x_val,y_val,x_test,y_test = load_cifar10("cifar_data",channels_last=True)

NUM_CLASSES = 10
cifar10_classes = ["airplane", "automobile", "bird", "cat", "deer", 
                   "dog", "frog", "horse", "ship", "truck"]

print("Train samples:", x_train.shape, y_train.shape)
print("Test samples:", x_test.shape, y_test.shape)
print("Val samples:", x_val.shape, y_val.shape)
# Out:
# Dataset not found. Downloading...
# Train samples: (40000, 32, 32, 3) (40000,)
# Test samples: (10000, 32, 32, 3) (10000,)
# Val samples: (10000, 32, 32, 3) (10000,)

# %%
# show some random images from train, and their labels

cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 2.5 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_train))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_train[random_index, :])
        ax.set_title(cifar10_classes[y_train[random_index]])
plt.show()

# %%
# normalize inputs
# convert class labels to one-hot encoded, should have shape (?, NUM_CLASSES)
# x_train = x_train.astype(np.float64) - 0.5

y_train = keras.utils.to_categorical(y_train, num_classes=10)

y_val = keras.utils.to_categorical(y_val, num_classes=10)

y_test = keras.utils.to_categorical(y_test, num_classes=10)

# %%
# import necessary building blocks
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU

# %%
def make_model():
    """
    Define your model architecture here.
    Returns `Sequential` model.
    """

    ### STUDENT CODE HERE ###
    
    model = Sequential()
    #groups a linear stack of layers into a `tf.keras.Model`

    model.add(Conv2D(32, (3, 3), strides = 1, padding='same', activation='relu', input_shape=x_train.shape[1:]))
    #A value of 32 neurons is chosen to focus on the low-level details within a 3-by-3 Kernel

    model.add(BatchNormalization())
    #The BatchNormalization applies a transformation that maintains the mean output close to 0 and the output standard deviation close to 1.
    #The normalisation process is used to draw the model to more general areas from where to learn from

    model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D((2, 2)))
    #Downsamples the input representation by taking the maximum value over the window defined by `pool_size` for each dimension along the features axis.
    #The window is shifted by `strides` in each dimension.  The resulting output when using "valid" padding option has a shape(number of rows or columns) of: `output_shape = (input_shape - pool_size + 1) / strides)`
    
    model.add(Dropout(0.2)) 
    #The Dropout layer randomly sets input units to 0 with a frequency of `rate` at each step during training time, which helps prevent overfitting of the model
    #A value of 0.2 is chosen to not overdue this process while remaining its functionality (20% of neurons not used)


    #Each following Layer is following the same approach: *

    #* Each layer increases in detail by using more Neurons than the previous one to pick up and remember more detail to make predictions
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2)) 

    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2)) 
    
    model.add(Flatten())
    #Turn the result into a 1D array without affecting batch size

    
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    #Add dense layers to combine the relevant features learned by the kernels
    #ReLU is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero.
    #It is used to only output positive values and ignore negative ones

    
    model.add(Dropout(0.1)) 
    #Regularize with dropout

    
    model.add(Dense(10, activation='softmax'))
    #Last layer with one neuron for each class

    model.summary()
    #Show a quick summary of the model building process 

    ### END STUDENT CODE ### 

    return model

# %%
### STUDENT CODE HERE ###

INIT_LR = 5e-3  # initial learning rate
BATCH_SIZE = 128
EPOCHS = 50
#The above values are used to not have datachuncks with a lot of data and enough learning runs to allow to make for accurate predictions

K.clear_session()  # clear default graph
# don't call K.set_learning_phase() !!! (otherwise will enable dropout in train/test simultaneously)

model = make_model()  # define our model

# prepare model for fitting (loss, optimizer, etc)
model.compile(
    loss='categorical_crossentropy',  # we train 10-way classification
    optimizer=keras.optimizers.Adamax(lr=INIT_LR),  # for SGD.
    metrics=['accuracy']  # report accuracy during training
)

my_callbacks = [tf.keras.callbacks.EarlyStopping(patience=10)] 
#To recognise early stop after 10 epochs with no increasing accuracy

# fit model
history = model.fit(
    x_train, y_train,  # prepared data
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(x_val, y_val),
    shuffle=True,
)

# save weights to file to avoid re-training
model.save_weights("weights.h5")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                131136
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 424,746
# Trainable params: 423,850
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/50
# 313/313 [==============================] - 39s 19ms/step - loss: 2.0020 - accuracy: 0.3147 - val_loss: 2.5810 - val_accuracy: 0.2195
# Epoch 2/50
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2327 - accuracy: 0.5617 - val_loss: 1.2074 - val_accuracy: 0.5874
# Epoch 3/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.9554 - accuracy: 0.6676 - val_loss: 1.0929 - val_accuracy: 0.6325
# Epoch 4/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.8007 - accuracy: 0.7218 - val_loss: 0.8665 - val_accuracy: 0.7072
# Epoch 5/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.7119 - accuracy: 0.7529 - val_loss: 0.7344 - val_accuracy: 0.7503
# Epoch 6/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.6211 - accuracy: 0.7837 - val_loss: 0.6803 - val_accuracy: 0.7673
# Epoch 7/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5620 - accuracy: 0.8044 - val_loss: 0.6854 - val_accuracy: 0.7691
# Epoch 8/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5014 - accuracy: 0.8256 - val_loss: 0.6227 - val_accuracy: 0.7935
# Epoch 9/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4500 - accuracy: 0.8443 - val_loss: 0.6112 - val_accuracy: 0.8018
# Epoch 10/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4076 - accuracy: 0.8592 - val_loss: 0.6689 - val_accuracy: 0.7803
# Epoch 11/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3631 - accuracy: 0.8743 - val_loss: 0.5985 - val_accuracy: 0.8062
# Epoch 12/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3388 - accuracy: 0.8811 - val_loss: 0.6134 - val_accuracy: 0.8104
# Epoch 13/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3096 - accuracy: 0.8931 - val_loss: 0.5562 - val_accuracy: 0.8260
# Epoch 14/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.2763 - accuracy: 0.9046 - val_loss: 0.6300 - val_accuracy: 0.8084
# Epoch 15/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.2606 - accuracy: 0.9074 - val_loss: 0.6229 - val_accuracy: 0.8137
# Epoch 16/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.2357 - accuracy: 0.9178 - val_loss: 0.6101 - val_accuracy: 0.8187
# Epoch 17/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.2282 - accuracy: 0.9196 - val_loss: 0.6158 - val_accuracy: 0.8265
# Epoch 18/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.2140 - accuracy: 0.9255 - val_loss: 0.6550 - val_accuracy: 0.8143
# Epoch 19/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1977 - accuracy: 0.9314 - val_loss: 0.6921 - val_accuracy: 0.7999
# Epoch 20/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1893 - accuracy: 0.9358 - val_loss: 0.6660 - val_accuracy: 0.8202
# Epoch 21/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1693 - accuracy: 0.9420 - val_loss: 0.6930 - val_accuracy: 0.8130
# Epoch 22/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1584 - accuracy: 0.9444 - val_loss: 0.6605 - val_accuracy: 0.8252
# Epoch 23/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1592 - accuracy: 0.9436 - val_loss: 0.6824 - val_accuracy: 0.8216
# Epoch 24/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1550 - accuracy: 0.9470 - val_loss: 0.6958 - val_accuracy: 0.8186
# Epoch 25/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1387 - accuracy: 0.9501 - val_loss: 0.6652 - val_accuracy: 0.8285
# Epoch 26/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1292 - accuracy: 0.9562 - val_loss: 0.6597 - val_accuracy: 0.8337
# Epoch 27/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1290 - accuracy: 0.9574 - val_loss: 0.6690 - val_accuracy: 0.8342
# Epoch 28/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1183 - accuracy: 0.9581 - val_loss: 0.6712 - val_accuracy: 0.8333
# Epoch 29/50
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1191 - accuracy: 0.9595 - val_loss: 0.6917 - val_accuracy: 0.8343
# Epoch 30/50
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1145 - accuracy: 0.9595 - val_loss: 0.7214 - val_accuracy: 0.8272
# Epoch 31/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1107 - accuracy: 0.9607 - val_loss: 0.7248 - val_accuracy: 0.8281
# Epoch 32/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0986 - accuracy: 0.9661 - val_loss: 0.7141 - val_accuracy: 0.8302
# Epoch 33/50
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1081 - accuracy: 0.9622 - val_loss: 0.6733 - val_accuracy: 0.8385
# Epoch 34/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0931 - accuracy: 0.9660 - val_loss: 0.7646 - val_accuracy: 0.8290
# Epoch 35/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0996 - accuracy: 0.9662 - val_loss: 0.7028 - val_accuracy: 0.8366
# Epoch 36/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0928 - accuracy: 0.9681 - val_loss: 0.7530 - val_accuracy: 0.8324
# Epoch 37/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0885 - accuracy: 0.9687 - val_loss: 0.7267 - val_accuracy: 0.8359
# Epoch 38/50
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0856 - accuracy: 0.9692 - val_loss: 0.8065 - val_accuracy: 0.8236
# Epoch 39/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0844 - accuracy: 0.9717 - val_loss: 0.8126 - val_accuracy: 0.8269
# Epoch 40/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0792 - accuracy: 0.9721 - val_loss: 0.8820 - val_accuracy: 0.8213
# Epoch 41/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0759 - accuracy: 0.9742 - val_loss: 0.7672 - val_accuracy: 0.8341
# Epoch 42/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0786 - accuracy: 0.9733 - val_loss: 0.7212 - val_accuracy: 0.8384
# Epoch 43/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0736 - accuracy: 0.9745 - val_loss: 0.7838 - val_accuracy: 0.8358
# Epoch 44/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0741 - accuracy: 0.9748 - val_loss: 0.7429 - val_accuracy: 0.8376
# Epoch 45/50
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0750 - accuracy: 0.9746 - val_loss: 0.7360 - val_accuracy: 0.8426
# Epoch 46/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0660 - accuracy: 0.9762 - val_loss: 0.7563 - val_accuracy: 0.8417
# Epoch 47/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0701 - accuracy: 0.9756 - val_loss: 0.8096 - val_accuracy: 0.8348
# Epoch 48/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0676 - accuracy: 0.9767 - val_loss: 0.7670 - val_accuracy: 0.8415
# Epoch 49/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0697 - accuracy: 0.9760 - val_loss: 0.8705 - val_accuracy: 0.8275
# Epoch 50/50
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0704 - accuracy: 0.9757 - val_loss: 0.7645 - val_accuracy: 0.8396

# %%
# load weights from file (can call without model.fit)
model.load_weights("weights.h5")

# %%
# make test predictions
y_pred_test = model.predict_proba(x_test)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_pred_test_max_probas = np.max(y_pred_test, axis=1)
y_test_index = [list(onehot).index(1) for onehot in y_test]

# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test_index, y_pred_test_classes))
plt.xticks(np.arange(10), cifar10_classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), cifar10_classes, fontsize=12)
plt.colorbar()
plt.show()
print("Test accuracy:", accuracy_score(y_test_index, y_pred_test_classes))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# Test accuracy: 0.8398

# %% [markdown]
# Overall pretty accurate only slight missprediction happens between dogs and cats which is understandable

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

# %%
# inspect preditions
cols = 10
rows = 3
fig = plt.figure(figsize=(2 * cols - 1, 3 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_test))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_test[random_index, :])
        pred_label = cifar10_classes[y_pred_test_classes[random_index]]
        pred_proba = y_pred_test_max_probas[random_index]
        true_label = cifar10_classes[y_test_index[random_index]]
        ax.set_title("pred: {}\nprob: {:.3}\ntrue: {}".format(
               pred_label, pred_proba, true_label
        ))
plt.show()

# %%
score = 0
for i in range (len(y_test_index)):
  if (y_test_index[i] == y_pred_test_classes[i]):
    score = score + 1

print(str(score/len(y_test_index)*100) + "%")
# Out:
# 83.98%

# %% [markdown]
# Accuracy of **84%** is a good result for a learning process of this time.
#
# The code produces a very good amount of very accurate predictions

# %% [markdown]
# ---

# %% [markdown]
# # Code Description

# %% [markdown]
# This code uses a 3 colvolutional layered model to predict the label of images.
#
# Firstly, the neural network is fed with a database of stock pictures and their respective label from one of the ten categories.
#
# Each of my three layers adds another degree of accuracy and detail in finding patters and shapes of the input pictures. This training is repeated a set of (Epoch) times over sets of data chuncks. This will allow the neural network to detect patterns and detail like faces.
#
# Afterwards, the neural network has to predict the label of another dataset of pictures using only the learning process mentioned above. It will also estimate a probability of which its prediction is correct.
#
# Details are mentioned in the code above in the creation of the model. Each layers constists of a sampling and a pooling stage

# %% [markdown]
# ---

# %% [markdown]
# # Some tips on how to improve:
#
# * The ultimate quest is to create a network that has as high __accuracy__ as you can push it.
#
# ## Potential grading:
# * starting at zero points
# * +2 for describing your iteration path in a report below.
# * +2 for building a network that gets above 20% accuracy
# * +1 for beating each of these milestones on __TEST__ dataset:
#     * 50% (5 total)
#     * 60% (6 total)
#     * 65% (7 total)
#     * 70% (8 total)
#     * 75% (9 total)
#     * 80% (10 total)
#
# ## Bonus points
# Common ways to get bonus points are:
# * Get higher score, obviously.
# * Anything special about your NN. For example \"A super-small/fast NN that gets 80%\" gets a bonus.
# * Any detailed analysis of the results. (saliency maps, whatever)
#
#
# ## Tips on what can be done:
#
#  * __Network size__
#    * More neurons,
#    * More layers, ([lasagne docs](http://lasagne.readthedocs.org))
#    * Nonlinearities in the hidden layers
#    * tanh, relu, leaky relu, etc
#    * Larger networks may take more epochs to train, so don't discard your net just because it could didn't beat the baseline in 5 epochs.
#
#  * __Convolution layers__
#    * they __are a must__ unless you have any super-ideas
#    * `network = lasagne.layers.Conv2DLayer(prev_layer,`
#      `                       num_filters = n_neurons,`
#      `                       filter_size = (filter width, filter height),`
#      `                       nonlinearity = some_nonlinearity)`
#    * Warning! Training convolutional networks can take long without GPU. That's okay.
#      * If you are CPU-only, we still recomment to try a simple convolutional architecture
#      * a perfect option is if you can set it up to run at nighttime and check it up at the morning.
#      * Make reasonable layer size estimates. A 128-neuron first convolution is likely an overkill.
#      * __To reduce computation__ time by a factor in exchange for some accuracy drop, try using __stride__ parameter. A stride=2 convolution should take roughly 1/4 of the default (stride=1) one.
#
#    * Plenty other layers and architectures
#      * http://lasagne.readthedocs.org/en/latest/modules/layers.html
#      * batch normalization, pooling, etc
#
#
#  * __Early Stopping__
#    * Training for 100 epochs regardless of anything is probably a bad idea.
#    * Some networks converge over 5 epochs, others - over 500.
#    * Way to go: stop when validation score is 10 iterations past maximum
#
#
#  * __Faster optimization__ -
#    * rmsprop, nesterov_momentum, adam, adagrad and so on.
#      * Converge faster and sometimes reach better optima
#      * It might make sense to tweak learning rate/momentum, other learning parameters, batch size and number of epochs
#    * __BatchNormalization__ (lasagne.layers.batch_norm) FTW!
#
#
#  * __Regularize__ to prevent overfitting
#    * Add some L2 weight norm to the loss function, theano will do the rest
#      * Can be done manually or via - http://lasagne.readthedocs.org/en/latest/modules/regularization.html
#    * Dropout - to prevent overfitting
#      * `lasagne.layers.DropoutLayer(prev_layer, p=probability_to_zero_out)`
#      * Don't overdo it. Check if it actually makes your network better
#
#
#  * __Data augmentation__ - getting 5x as large dataset for free is a great deal
#    * Zoom-in+slice = move
#    * Rotate+zoom(to remove black stripes)
#    * any other perturbations
#    * Add Noize (easiest: GaussianNoizeLayer)
#    * Simple way to do that (if you have PIL/Image):
#      * ```from scipy.misc import imrotate,imresize```
#      * and a few slicing
#    * Stay realistic. There's usually no point in flipping dogs upside down as that is not the way you usually see them.
